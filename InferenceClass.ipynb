# %%
import os
from YoloKit.inference import YoloInference
from YoloKit.Utils import create_dir

# %%
volume_dir = "Data/W22273-v2"
parquet_output_dir = os.path.join(volume_dir, "Output", "Parquet")
preview_output_dir = os.path.join(volume_dir, "Output", "Preview")

model_checkpoint = "Models/TinyYolo_2a/weights/best.pt"
yolo_inference = YoloInference(model_checkpoint)

# %%
yolo_inference.generate_debug_output(volume_dir, preview_output_dir)
# Out:
#   0%|          | 0/870 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 yolo_inference.generate_debug_output(volume_dir, preview_output_dir)
#
# File ~/Desktop/Projects/Python/yolo-segmentation/YoloKit/inference.py:201, in YoloInference.generate_debug_output(self, directory, out_dir, alpha)
#     198 results = self._run_prediction(tile_data)
#     200 # TODO: handle cpu and gpu post_process_mode
# --> 201 merged_masks = self._post_process_cpu(results, tile_data, img_padded)
#     203 if len(merged_masks) == 0:
#     204     continue
#
# File ~/Desktop/Projects/Python/yolo-segmentation/YoloKit/inference.py:71, in YoloInference._post_process_cpu(self, results, tile_data, image)
#      68     return []
#      70 clusters = cluster_lines(y_centers_raw, dup_eps=8, spacing_factor=0.5)
# ---> 71 return merge_line_masks(global_masks, clusters)
#
# File ~/Desktop/Projects/Python/yolo-segmentation/YoloKit/Processing/image.py:603, in merge_line_masks(global_masks, clusters)
#     601     line_mask = np.zeros_like(global_masks[0])
#     602     for idx in cluster:
# --> 603         line_mask |= global_masks[idx]
#     604     merged.append(line_mask)
#     606 return merged
#
# TypeError: unsupported operand type(s) for |=: 'numpy.ndarray' and 'Tensor'
